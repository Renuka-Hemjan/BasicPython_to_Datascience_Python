# %%
# Object: it is every entity around us. object have two thing:
# object attribute: eg laptop's width ,length ,companies
# object function: eg it display,work.
# Class: A class is a blueprint fron which objects are created.

# %%
class Student:
    name='ritu'
    age=20
    def sdetail(self):
        print(self.name)
        print(self.age)

s = Student()
s.sdetail()
print(s.name)
# Out:
# ritu
# 20

# %%
class Student:
    fee = 25000
    increment = 0.1*fee + fee
    def sdetail(self):
        print(self.fee)
        print(self.increment)
s = Student()
s.sdetail()
# Out:
# 25000
# 27500.0

# %%
class Student:
    name='ritu'
    age=20
    fee = 10000
    def sdetail(self):
        print(self.name)
        print(self.age)
    def fee_detail(self):
        val = self.fee * 0.1
        print(f'10% of fee is : {val}')
        total = self.fee +val
        print(f'total fee is : {total}')
    def  registration_fee (self,regis):
        totalfee = s.fee +  regis
        print(f'total fee including registration charge is : {totalfee}')
        
    

s = Student()
s.sdetail()
print(s.name)
s.fee_detail()
s.registration_fee(2000)
# Out:
# ritu
# 20
# ritu
# 10% of fee is : 1000.0
# total fee is : 11000.0
# total fee including registration charge is : 12000

# %%
class Employee:
    name ='abcd'
    department = 'It'
    salary = 10000
    def edetail(self):
        print(self.name)
        print(self.department)
    def salary_detail(self):
        val = self.salary -self.salary * 0.2
        print(f'final salary after deducting 20% is {val}')
    def bonus_salary(self,bonus):
        total_salary = self.salary + bonus
        print(f'salary after adding bonus:{total_salary}')
s = Employee()
s.edetail()
s.salary_detail()
s.bonus_salary(1000)
# Out:
# abcd
# It
# final salary after deducting 20% is 8000.0
# salary after adding bonus:11000
