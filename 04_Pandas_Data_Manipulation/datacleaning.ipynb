# %%
# data cleaning

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name":["Ram","Krishna","Sita","Gita","srijala","pabitra"],
    "Age":[25,30,  np.nan,30,28,38],
    "City":["Ktm","brt", "rjb",None,None,"ltp"],
    "Salary":[5000,6000,7000,6000,np.nan,9000]
}
df = pd.DataFrame(data)
df
cpydf =df
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0
# 2     Sita   NaN  rjb  7000.0
# 3     Gita  30.0  NaN  6000.0
# 4      NaN  28.0  NaN     NaN

# %%
df.isnull()
# Out:
#     Name    Age   City  Salary
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False   True  False   False
# 3  False  False   True   False
# 4   True  False   True    True

# %%
df.isnull().sum() #find out how mNY NULL
# Out:
# Name      1
# Age       1
# City      2
# Salary    1
# dtype: int64

# %%
#deleting null row
df.dropna()
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0

# %%
ndf = df.dropna() #new data frame

# %%
ndf
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0

# %%
#deleting null in column
cdf = df.dropna(axis=1)
cdf
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df_clean = df.dropna(axis=0) #delete all the row that have null
df_clean
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0

# %%
#cols_with_nan = df.columns[df.isnull().any()]
#df = df.drop(columns=cols_with_nan)

# %%
# filling missing value with zero
dfz = df.fillna(0)
dfz
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0
# 2     Sita   0.0  rjb  7000.0
# 3     Gita  30.0    0  6000.0
# 4        0  28.0    0     0.0

# %%
dfz = df.fillna(1)
dfz
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0
# 2     Sita   1.0  rjb  7000.0
# 3     Gita  30.0    1  6000.0
# 4        1  28.0    1     1.0

# %%
df
# Out:
#       Name   Age City  Salary
# 0      Ram  25.0  Ktm  5000.0
# 1  Krishna  30.0  brt  6000.0
# 2     Sita   NaN  rjb  7000.0
# 3     Gita  30.0  NaN  6000.0
# 4      NaN  28.0  NaN     NaN

# %%
# fillinfg with age coulmn with mean value
mean_age = df['Age'].mean()

# %%
df["Age"] = df["Age"].fillna(mean_age)

# %%
df
# Out:
#       Name    Age City  Salary
# 0      Ram  25.00  Ktm  5000.0
# 1  Krishna  30.00  brt  6000.0
# 2     Sita  28.25  rjb  7000.0
# 3     Gita  30.00  NaN  6000.0
# 4      NaN  28.00  NaN     NaN

# %%
df["Age"] = df["Age"].fillna(df['Age'].median())

# %%
df
# Out:
#       Name    Age City  Salary
# 0      Ram  25.00  Ktm  5000.0
# 1  Krishna  30.00  brt  6000.0
# 2     Sita  28.25  rjb  7000.0
# 3     Gita  30.00  NaN  6000.0
# 4      NaN  28.00  NaN     NaN

# %%
df
# Out:
#       Name    Age City  Salary
# 0      Ram  25.00  Ktm  5000.0
# 1  Krishna  30.00  brt  6000.0
# 2     Sita  28.25  rjb  7000.0
# 3     Gita  30.00  NaN  6000.0
# 4      NaN  28.00  NaN     NaN

# %%
#forward filled
#df = df.ffill()

# %%
#df
# Out:
#       Name    Age City  Salary
# 0      Ram  25.00  Ktm  5000.0
# 1  Krishna  30.00  brt  6000.0
# 2     Sita  28.25  rjb  7000.0
# 3     Gita  30.00  rjb  6000.0
# 4     Gita  28.00  rjb  6000.0

# %%
df = df.bfill()

# %%
df
# Out:
#       Name    Age City  Salary
# 0      Ram  25.00  Ktm  5000.0
# 1  Krishna  30.00  brt  6000.0
# 2     Sita  28.25  rjb  7000.0
# 3     Gita  30.00  rjb  6000.0
# 4     Gita  28.00  rjb  6000.0

# %%
#
duplicates = df.duplicated()

# %%
duplicates
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       Name    Age City  Salary
# 0      Ram  25.00  Ktm  5000.0
# 1  Krishna  30.00  brt  6000.0
# 2     Sita  28.25  rjb  7000.0
# 3     Gita  30.00  rjb  6000.0
# 4     Gita  28.00  rjb  6000.0
