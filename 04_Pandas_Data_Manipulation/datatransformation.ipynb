# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name":["Rakesh","Sikha","Anil","Priya","Anya","Anya],
    "Age":[25,30,22,28,35,5],
    "Salary":[5000,7000,4500,6500,8000,2000],
    "City":["Rajbiraj","Biratnagar","Kathmandu","Pokhara","Kathmandu","pokhara"]
})

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 4    ANYA  420    8000   Kathmandu  9600.0       5040
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 2    ANIL  264    4500   Kathmandu  5400.0       3168

# %%
df['Bnous'] = df['Salary'] * 1.20 # add bonus in salary

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  Rakesh   25    5000    Rajbiraj  6000.0
# 1   Sikha   30    7000  Biratnagar  8400.0
# 2    Anil   22    4500   Kathmandu  5400.0
# 3   Priya   28    6500     Pokhara  7800.0
# 4    Anya   35    8000   Kathmandu  9600.0

# %%
df['Name']= df['Name'].str.upper()#changinf into capital

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  RAKESH   25    5000    Rajbiraj  6000.0
# 1   SIKHA   30    7000  Biratnagar  8400.0
# 2    ANIL   22    4500   Kathmandu  5400.0
# 3   PRIYA   28    6500     Pokhara  7800.0
# 4    ANYA   35    8000   Kathmandu  9600.0

# %%
df['City'] = df['City'].str.lower()

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  RAKESH   25    5000    rajbiraj  6000.0
# 1   SIKHA   30    7000  biratnagar  8400.0
# 2    ANIL   22    4500   kathmandu  5400.0
# 3   PRIYA   28    6500     pokhara  7800.0
# 4    ANYA   35    8000   kathmandu  9600.0

# %%
df['City'] = df['City'].str.title()

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  RAKESH   25    5000    Rajbiraj  6000.0
# 1   SIKHA   30    7000  Biratnagar  8400.0
# 2    ANIL   22    4500   Kathmandu  5400.0
# 3   PRIYA   28    6500     Pokhara  7800.0
# 4    ANYA   35    8000   Kathmandu  9600.0

# %%
df['City'] = df['City'].replace('Kathmandu','Kathmandu capital')

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  RAKESH   25    5000    Rajbiraj  6000.0
# 1   SIKHA   30    7000  Biratnagar  8400.0
# 2    ANIL   22    4500   Kathmandu  5400.0
# 3   PRIYA   28    6500     Pokhara  7800.0
# 4    ANYA   35    8000   Kathmandu  9600.0

# %% [raw]
# gender = {
#     "Rakesh": "Male",
#     "Sikha": "Female",
#     "Anil": "Male",
#     "Priya": "Female",
#     "Anya": "Female"
# }

# %%
df['Gender']= df['Name'].map(gender)

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  RAKESH   25    5000    Rajbiraj  6000.0
# 1   SIKHA   30    7000  Biratnagar  8400.0
# 2    ANIL   22    4500   Kathmandu  5400.0
# 3   PRIYA   28    6500     Pokhara  7800.0
# 4    ANYA   35    8000   Kathmandu  9600.0

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['RAKESH', 'SIKHA', 'ANIL', 'PRIYA', 'ANYA']
# Length: 5, dtype: str

# %%
df["Age"] = df["Age"] * 12

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous
# 0  RAKESH  300    5000    Rajbiraj  6000.0
# 1   SIKHA  360    7000  Biratnagar  8400.0
# 2    ANIL  264    4500   Kathmandu  5400.0
# 3   PRIYA  336    6500     Pokhara  7800.0
# 4    ANYA  420    8000   Kathmandu  9600.0

# %%
df['Age_month']= df['Age'] *12

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 2    ANIL  264    4500   Kathmandu  5400.0       3168
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 4    ANYA  420    8000   Kathmandu  9600.0       5040

# %%
sorted_df = df.sort_values(by = 'Age')

# %%
sorted_df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 2    ANIL  264    4500   Kathmandu  5400.0       3168
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 4    ANYA  420    8000   Kathmandu  9600.0       5040

# %%
sorted_df = df.sort_values(by = 'Age', ascending = False)

# %%
sorted_df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 4    ANYA  420    8000   Kathmandu  9600.0       5040
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 2    ANIL  264    4500   Kathmandu  5400.0       3168

# %%
df.sort_values(by = ["Age","Salary"], ascending = [False,True], inplace = True)

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 4    ANYA  420    8000   Kathmandu  9600.0       5040
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 2    ANIL  264    4500   Kathmandu  5400.0       3168

# %%
df.sort_values(by="Age",inplace=True)

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 2    ANIL  264    4500   Kathmandu  5400.0       3168
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 4    ANYA  420    8000   Kathmandu  9600.0       5040

# %%
df.sort_values(by="Age").reset_index(drop=True)
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 0    ANIL  264    4500   Kathmandu  5400.0       3168
# 1  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 2   PRIYA  336    6500     Pokhara  7800.0       4032
# 3   SIKHA  360    7000  Biratnagar  8400.0       4320
# 4    ANYA  420    8000   Kathmandu  9600.0       5040

# %%
df = df[df['Age'] >270]

# %%
df
# Out:
#      Name  Age  Salary        City   Bnous  Age_month
# 0  RAKESH  300    5000    Rajbiraj  6000.0       3600
# 3   PRIYA  336    6500     Pokhara  7800.0       4032
# 1   SIKHA  360    7000  Biratnagar  8400.0       4320
# 4    ANYA  420    8000   Kathmandu  9600.0       5040

# %%
df = df[(df['Age'] >270)&(df['Salary']<8000)]

# %%
df
# Out:
#      Name  Age  Salary      City   Bnous  Age_month
# 0  RAKESH  300    5000  Rajbiraj  6000.0       3600

# %%
df = df[(df['Age'] > 250) & (df['City'].isin(["kathmandu"]))]

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Salary, City, Bnous, Age_month]
# Index: []

# %%
ctni df[~df["Cit
